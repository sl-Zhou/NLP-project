# %%
from google.colab import drive
import os

drive.mount('/content/drive')


# !nvidia-smi
# Out:
# Mounted at /content/drive
# Sat Apr 27 15:46:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   39C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install datasets==2.11.0 --quiet
# !pip install accelerate  --quiet
# !pip install evaluate   --quiet
# !pip install rouge_score --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done

# %%
import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer
from torch import nn
from tqdm import tqdm
from tqdm.auto import trange
import torch
from datasets import Dataset

def load(repo_id, load_in_8bit=False):
    return (
        AutoModelForCausalLM.from_pretrained(
            repo_id, device_map='auto', load_in_8bit=load_in_8bit
        ),
        AutoTokenizer.from_pretrained(repo_id)
    )

teacher, tokenizer = load("EleutherAI/pythia-160m", False)
tokenizer.pad_token = tokenizer.eos_token
teacher = teacher.to(torch.bfloat16).cuda()

student = load("EleutherAI/pythia-70m")[0]

student = student.cuda().to(torch.bfloat16)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/569 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/375M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/567 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/166M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
csv_path = "/content/drive/MyDrive/project/Jfleg4-2-4.csv"
df = pd.read_csv(csv_path)
dataset = Dataset.from_pandas(df)
split_dataset = dataset.train_test_split(test_size=0.1, shuffle=True, seed=123)
train_dataset = split_dataset["train"]
test_dataset = split_dataset["test"]
train_df = train_dataset.to_pandas()

# %%
lr = 1e-4
train_max_length = 1024
batch_size = 4
grad_acc_steps = 128
total_steps = 256
distil_temp = 1.3
alpha = 0.5

optim = torch.optim.AdamW(student.parameters(), lr)
scheduler = torch.optim.lr_scheduler.LinearLR(optim, start_factor=1, end_factor=0.1, total_iters=total_steps)
logit_loss_fn = nn.KLDivLoss(reduction="batchmean")
logit_accumulator = 0
loss_accumulator = 0

def get_next():
    global next_index
    input_text = train_df['input'].iloc[next_index]
    target_text = train_df['target'].iloc[next_index]
    next_index = (next_index + 1) % len(train_df)
    return input_text, target_text

next_index = 0

for i in trange(total_steps*grad_acc_steps):
    text = [get_next() for i in range(batch_size)]
    losses = {}
    tokenized = {
        k:v.cuda() for k,v in tokenizer(
            [t[0] for t in text], return_tensors="pt", truncation=True, padding=True
        ).items()
    }
    input_ids = tokenized['input_ids'][...,:train_max_length]
    attention_mask = tokenized['attention_mask'][...,:train_max_length]
    targ_logits = teacher(input_ids).logits.clone().detach()
    student_out = student(input_ids, labels=input_ids)
    logits = student_out.logits
    loss = student_out.loss
    s_logits = logits
    t_logits = targ_logits
    mask = attention_mask.unsqueeze(-1).expand_as(s_logits)
    s_logits_slct = s_logits.view(-1, s_logits.size(-1))
    t_logits_slct = t_logits.view(-1, s_logits.size(-1))
    loss_ce = (
        logit_loss_fn(
            nn.functional.log_softmax(s_logits_slct / distil_temp, dim=-1),
            nn.functional.softmax(t_logits_slct / distil_temp, dim=-1),
        )
        * (distil_temp) ** 2
    )
    logit_loss = loss_ce
    ((loss*(1-alpha) + logit_loss*alpha) / grad_acc_steps).backward()
    loss_accumulator+=loss.item()/grad_acc_steps
    logit_accumulator+=logit_loss.item()/grad_acc_steps
    if (i+1)%grad_acc_steps==0:
        optim.step()
        optim.zero_grad()
        scheduler.step()
        losses['Student Loss'] = loss_accumulator
        losses['Student Perplexity'] = torch.exp(
            torch.tensor(loss_accumulator)
        ).item()
        losses['Distillation Loss'] = logit_accumulator
        losses['Learning Rate'] = scheduler.get_last_lr()[0]
        print(losses)
        loss_accumulator = 0
        logit_accumulator = 0
# Save the model
model_save_path = '/content/drive/MyDrive/project/model/distillpythia'
tokenizer_save_path = '/content/drive/MyDrive/project/model/tokenizer/distillpythia'
student.save_pretrained(model_save_path)
tokenizer.save_pretrained(tokenizer_save_path)
# Out:
#   0%|          | 0/32768 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# {'Student Loss': 7.656494140625, 'Student Perplexity': 2114.331787109375, 'Distillation Loss': 4.0606689453125, 'Learning Rate': 9.96484375e-05}
# {'Student Loss': 5.3653564453125, 'Student Perplexity': 213.86744689941406, 'Distillation Loss': 5.16455078125, 'Learning Rate': 9.9296875e-05}
# {'Student Loss': 5.119384765625, 'Student Perplexity': 167.23245239257812, 'Distillation Loss': 5.480224609375, 'Learning Rate': 9.894531250000001e-05}
# {'Student Loss': 4.6640625, 'Student Perplexity': 106.06610107421875, 'Distillation Loss': 7.233642578125, 'Learning Rate': 9.859375000000001e-05}
# {'Student Loss': 4.8714599609375, 'Student Perplexity': 130.51132202148438, 'Distillation Loss': 5.090576171875, 'Learning Rate': 9.824218750000001e-05}
# {'Student Loss': 5.03125, 'Student Perplexity': 153.12429809570312, 'Distillation Loss': 5.01513671875, 'Learning Rate': 9.789062500000001e-05}
# {'Student Loss': 5.0557861328125, 'Student Perplexity': 156.92784118652344, 'Distillation Loss': 5.071044921875, 'Learning Rate': 9.753906250000001e-05}
# {'Student Loss': 5.212890625, 'Student Perplexity': 183.62408447265625, 'Distillation Loss': 5.2109375, 'Learning Rate': 9.718750000000001e-05}
# {'Student Loss': 5.118408203125, 'Student Perplexity': 167.0692138671875, 'Distillation Loss': 5.09130859375, 'Learning Rate': 9.683593750000001e-05}
# {'Student Loss': 5.0643310546875, 'Student Perplexity': 158.2745361328125, 'Distillation Loss': 4.850341796875, 'Learning Rate': 9.648437500000001e-05}
# {'Student Loss': 5.26611328125, 'Student Perplexity': 193.6617889404297, 'Distillation Loss': 4.736328125, 'Learning Rate': 9.613281250000001e-05}
# {'Student Loss': 5.17919921875, 'Student Perplexity': 177.54058837890625, 'Distillation Loss': 4.885986328125, 'Learning Rate': 9.578125000000001e-05}
# {'Student Loss': 4.993408203125, 'Student Perplexity': 147.4380645751953, 'Distillation Loss': 5.1044921875, 'Learning Rate': 9.542968750000001e-05}
# {'Student Loss': 5.144775390625, 'Student Perplexity': 171.532958984375, 'Distillation Loss': 5.199462890625, 'Learning Rate': 9.507812500000002e-05}
# {'Student Loss': 5.275146484375, 'Student Perplexity': 195.41909790039062, 'Distillation Loss': 5.24951171875, 'Learning Rate': 9.472656250000002e-05}
# {'Student Loss': 5.155517578125, 'Student Perplexity': 173.38552856445312, 'Distillation Loss': 5.259765625, 'Learning Rate': 9.437500000000002e-05}
# {'Student Loss': 5.3555908203125, 'Student Perplexity': 211.7890625, 'Distillation Loss': 5.277099609375, 'Learning Rate': 9.402343750000002e-05}
# {'Student Loss': 7.72021484375, 'Student Perplexity': 2253.443603515625, 'Distillation Loss': 4.7052001953125, 'Learning Rate': 9.367187500000002e-05}
# {'Student Loss': 7.595458984375, 'Student Perplexity': 1989.142578125, 'Distillation Loss': 4.7010498046875, 'Learning Rate': 9.332031250000002e-05}
# {'Student Loss': 7.41748046875, 'Student Perplexity': 1664.8336181640625, 'Distillation Loss': 4.76611328125, 'Learning Rate': 9.296875000000002e-05}
# {'Student Loss': 5.2340087890625, 'Student Perplexity': 187.54312133789062, 'Distillation Loss': 5.630615234375, 'Learning Rate': 9.261718750000002e-05}
# {'Student Loss': 5.176025390625, 'Student Perplexity': 176.97799682617188, 'Distillation Loss': 5.66650390625, 'Learning Rate': 9.226562500000002e-05}
# {'Student Loss': 5.117919921875, 'Student Perplexity': 166.98765563964844, 'Distillation Loss': 5.7255859375, 'Learning Rate': 9.191406250000002e-05}
# {'Student Loss': 6.9638671875, 'Student Perplexity': 1057.716064453125, 'Distillation Loss': 4.79443359375, 'Learning Rate': 9.156250000000002e-05}
# {'Student Loss': 6.9912109375, 'Student Perplexity': 1087.0369873046875, 'Distillation Loss': 4.712646484375, 'Learning Rate': 9.121093750000002e-05}
# {'Student Loss': 6.9658203125, 'Student Perplexity': 1059.783935546875, 'Distillation Loss': 4.754638671875, 'Learning Rate': 9.085937500000002e-05}
# {'Student Loss': 5.4935302734375, 'Student Perplexity': 243.11395263671875, 'Distillation Loss': 5.5625, 'Learning Rate': 9.050781250000003e-05}
# {'Student Loss': 5.321533203125, 'Student Perplexity': 204.69747924804688, 'Distillation Loss': 5.791015625, 'Learning Rate': 9.015625000000003e-05}
# {'Student Loss': 5.700439453125, 'Student Perplexity': 298.998779296875, 'Distillation Loss': 5.44970703125, 'Learning Rate': 8.980468750000003e-05}
# {'Student Loss': 6.337646484375, 'Student Perplexity': 565.4639282226562, 'Distillation Loss': 4.948974609375, 'Learning Rate': 8.945312500000003e-05}
# {'Student Loss': 6.14453125, 'Student Perplexity': 466.16107177734375, 'Distillation Loss': 5.07275390625, 'Learning Rate': 8.910156250000003e-05}
# {'Student Loss': 5.6451416015625, 'Student Perplexity': 282.9136047363281, 'Distillation Loss': 5.358154296875, 'Learning Rate': 8.875000000000003e-05}
# {'Student Loss': 5.6575927734375, 'Student Perplexity': 286.458251953125, 'Distillation Loss': 5.501953125, 'Learning Rate': 8.839843750000003e-05}
# {'Student Loss': 5.811767578125, 'Student Perplexity': 334.2093505859375, 'Distillation Loss': 5.21337890625, 'Learning Rate': 8.804687500000003e-05}
# {'Student Loss': 6.100830078125, 'Student Perplexity': 446.22802734375, 'Distillation Loss': 4.865478515625, 'Learning Rate': 8.769531250000003e-05}
# {'Student Loss': 6.281982421875, 'Student Perplexity': 534.847900390625, 'Distillation Loss': 4.63720703125, 'Learning Rate': 8.734375000000003e-05}
# {'Student Loss': 5.953125, 'Student Perplexity': 384.9544372558594, 'Distillation Loss': 5.106201171875, 'Learning Rate': 8.699218750000003e-05}
# {'Student Loss': 5.3670654296875, 'Student Perplexity': 214.23326110839844, 'Distillation Loss': 5.647216796875, 'Learning Rate': 8.664062500000003e-05}
# {'Student Loss': 5.39697265625, 'Student Perplexity': 220.73715209960938, 'Distillation Loss': 5.523681640625, 'Learning Rate': 8.628906250000003e-05}
# {'Student Loss': 5.8345947265625, 'Student Perplexity': 341.9261474609375, 'Distillation Loss': 5.41552734375, 'Learning Rate': 8.593750000000004e-05}
# {'Student Loss': 6.31591796875, 'Student Perplexity': 553.3097534179688, 'Distillation Loss': 4.74267578125, 'Learning Rate': 8.558593750000004e-05}
# {'Student Loss': 5.937255859375, 'Student Perplexity': 378.8937683105469, 'Distillation Loss': 5.00830078125, 'Learning Rate': 8.523437500000004e-05}
# {'Student Loss': 5.6553955078125, 'Student Perplexity': 285.8294982910156, 'Distillation Loss': 5.598388671875, 'Learning Rate': 8.488281250000004e-05}
# {'Student Loss': 5.4534912109375, 'Student Perplexity': 233.5721893310547, 'Distillation Loss': 5.48974609375, 'Learning Rate': 8.453125000000004e-05}
# {'Student Loss': 5.7315673828125, 'Student Perplexity': 308.4523620605469, 'Distillation Loss': 5.35693359375, 'Learning Rate': 8.417968750000004e-05}
# {'Student Loss': 5.855224609375, 'Student Perplexity': 349.05328369140625, 'Distillation Loss': 5.351806640625, 'Learning Rate': 8.382812500000004e-05}
# {'Student Loss': 5.99462890625, 'Student Perplexity': 401.26776123046875, 'Distillation Loss': 5.09228515625, 'Learning Rate': 8.347656250000004e-05}
# {'Student Loss': 5.71875, 'Student Perplexity': 304.5240173339844, 'Distillation Loss': 5.1083984375, 'Learning Rate': 8.312500000000004e-05}
# {'Student Loss': 5.896728515625, 'Student Perplexity': 363.84521484375, 'Distillation Loss': 5.5546875, 'Learning Rate': 8.277343750000004e-05}
# {'Student Loss': 5.6651611328125, 'Student Perplexity': 288.6344909667969, 'Distillation Loss': 5.45703125, 'Learning Rate': 8.242187500000004e-05}
# {'Student Loss': 5.76123046875, 'Student Perplexity': 317.7390441894531, 'Distillation Loss': 5.316162109375, 'Learning Rate': 8.207031250000004e-05}
# {'Student Loss': 5.99169921875, 'Student Perplexity': 400.0938720703125, 'Distillation Loss': 5.078125, 'Learning Rate': 8.171875000000004e-05}
# {'Student Loss': 6.0906982421875, 'Student Perplexity': 441.729736328125, 'Distillation Loss': 5.089599609375, 'Learning Rate': 8.136718750000005e-05}
# {'Student Loss': 5.6121826171875, 'Student Perplexity': 273.7410583496094, 'Distillation Loss': 5.4736328125, 'Learning Rate': 8.101562500000005e-05}
# {'Student Loss': 5.7314453125, 'Student Perplexity': 308.4147033691406, 'Distillation Loss': 5.449462890625, 'Learning Rate': 8.066406250000005e-05}
# {'Student Loss': 5.6173095703125, 'Student Perplexity': 275.14813232421875, 'Distillation Loss': 5.63818359375, 'Learning Rate': 8.031250000000005e-05}
# {'Student Loss': 5.700927734375, 'Student Perplexity': 299.1448059082031, 'Distillation Loss': 5.55810546875, 'Learning Rate': 7.996093750000005e-05}
# {'Student Loss': 5.8072509765625, 'Student Perplexity': 332.7032470703125, 'Distillation Loss': 5.436279296875, 'Learning Rate': 7.960937500000005e-05}
# {'Student Loss': 5.7606201171875, 'Student Perplexity': 317.5451965332031, 'Distillation Loss': 5.33349609375, 'Learning Rate': 7.925781250000005e-05}
# {'Student Loss': 5.6141357421875, 'Student Perplexity': 274.2762451171875, 'Distillation Loss': 5.702880859375, 'Learning Rate': 7.890625000000005e-05}
# {'Student Loss': 5.5927734375, 'Student Perplexity': 268.47918701171875, 'Distillation Loss': 5.57958984375, 'Learning Rate': 7.855468750000005e-05}
# {'Student Loss': 6.18017578125, 'Student Perplexity': 483.0768737792969, 'Distillation Loss': 5.101318359375, 'Learning Rate': 7.820312500000005e-05}
# {'Student Loss': 5.9365234375, 'Student Perplexity': 378.6163635253906, 'Distillation Loss': 5.13623046875, 'Learning Rate': 7.785156250000005e-05}
# {'Student Loss': 5.744140625, 'Student Perplexity': 312.3550720214844, 'Distillation Loss': 5.4697265625, 'Learning Rate': 7.750000000000005e-05}
# {'Student Loss': 5.69482421875, 'Student Perplexity': 297.32452392578125, 'Distillation Loss': 5.573974609375, 'Learning Rate': 7.714843750000005e-05}
# {'Student Loss': 5.559326171875, 'Student Perplexity': 259.6478271484375, 'Distillation Loss': 5.551025390625, 'Learning Rate': 7.679687500000006e-05}
# {'Student Loss': 5.98974609375, 'Student Perplexity': 399.3132019042969, 'Distillation Loss': 5.395263671875, 'Learning Rate': 7.644531250000006e-05}
# {'Student Loss': 6.01708984375, 'Student Perplexity': 410.382568359375, 'Distillation Loss': 5.1904296875, 'Learning Rate': 7.609375000000006e-05}
# {'Student Loss': 5.990966796875, 'Student Perplexity': 399.80096435546875, 'Distillation Loss': 5.31201171875, 'Learning Rate': 7.574218750000006e-05}
# {'Student Loss': 5.6353759765625, 'Student Perplexity': 280.16424560546875, 'Distillation Loss': 5.67333984375, 'Learning Rate': 7.539062500000006e-05}
# {'Student Loss': 5.722900390625, 'Student Perplexity': 305.7905578613281, 'Distillation Loss': 5.545654296875, 'Learning Rate': 7.503906250000006e-05}
# {'Student Loss': 5.865966796875, 'Student Perplexity': 352.8230895996094, 'Distillation Loss': 5.404541015625, 'Learning Rate': 7.468750000000006e-05}
# {'Student Loss': 6.1484375, 'Student Perplexity': 467.985595703125, 'Distillation Loss': 5.057373046875, 'Learning Rate': 7.433593750000006e-05}
# {'Student Loss': 5.68505859375, 'Student Perplexity': 294.4350891113281, 'Distillation Loss': 5.492431640625, 'Learning Rate': 7.398437500000006e-05}
# {'Student Loss': 5.669677734375, 'Student Perplexity': 289.9410705566406, 'Distillation Loss': 5.658447265625, 'Learning Rate': 7.363281250000006e-05}
# {'Student Loss': 5.7587890625, 'Student Perplexity': 316.9642639160156, 'Distillation Loss': 5.611328125, 'Learning Rate': 7.328125000000006e-05}
# {'Student Loss': 6.165283203125, 'Student Perplexity': 475.9359130859375, 'Distillation Loss': 5.2978515625, 'Learning Rate': 7.292968750000006e-05}
# {'Student Loss': 6.041015625, 'Student Perplexity': 420.3197021484375, 'Distillation Loss': 5.28173828125, 'Learning Rate': 7.257812500000007e-05}
# {'Student Loss': 5.575927734375, 'Student Perplexity': 263.9943542480469, 'Distillation Loss': 5.66650390625, 'Learning Rate': 7.222656250000007e-05}
# {'Student Loss': 5.67919921875, 'Student Perplexity': 292.7149353027344, 'Distillation Loss': 5.597900390625, 'Learning Rate': 7.187500000000007e-05}
# {'Student Loss': 5.841796875, 'Student Perplexity': 344.3976135253906, 'Distillation Loss': 5.492431640625, 'Learning Rate': 7.152343750000007e-05}
# {'Student Loss': 6.5927734375, 'Student Perplexity': 729.8021240234375, 'Distillation Loss': 5.009521484375, 'Learning Rate': 7.117187500000007e-05}
# {'Student Loss': 6.24560546875, 'Student Perplexity': 515.7413940429688, 'Distillation Loss': 5.132080078125, 'Learning Rate': 7.082031250000007e-05}
# {'Student Loss': 5.633544921875, 'Student Perplexity': 279.6517028808594, 'Distillation Loss': 5.62060546875, 'Learning Rate': 7.046875000000007e-05}
# {'Student Loss': 5.547607421875, 'Student Perplexity': 256.6228332519531, 'Distillation Loss': 5.645263671875, 'Learning Rate': 7.011718750000007e-05}
# {'Student Loss': 6.4281005859375, 'Student Perplexity': 618.9970703125, 'Distillation Loss': 5.125244140625, 'Learning Rate': 6.976562500000007e-05}
# {'Student Loss': 6.69775390625, 'Student Perplexity': 810.5831298828125, 'Distillation Loss': 5.018310546875, 'Learning Rate': 6.941406250000007e-05}
# {'Student Loss': 6.145263671875, 'Student Perplexity': 466.50262451171875, 'Distillation Loss': 5.166259765625, 'Learning Rate': 6.906250000000007e-05}
# {'Student Loss': 5.6202392578125, 'Student Perplexity': 275.9554138183594, 'Distillation Loss': 5.78466796875, 'Learning Rate': 6.871093750000007e-05}
# {'Student Loss': 5.6551513671875, 'Student Perplexity': 285.7597351074219, 'Distillation Loss': 5.7763671875, 'Learning Rate': 6.835937500000007e-05}
# {'Student Loss': 6.138916015625, 'Student Perplexity': 463.5508117675781, 'Distillation Loss': 5.335205078125, 'Learning Rate': 6.800781250000008e-05}
# {'Student Loss': 6.56689453125, 'Student Perplexity': 711.157958984375, 'Distillation Loss': 5.050048828125, 'Learning Rate': 6.765625000000008e-05}
# {'Student Loss': 6.22998046875, 'Student Perplexity': 507.7455749511719, 'Distillation Loss': 5.191162109375, 'Learning Rate': 6.730468750000008e-05}
# {'Student Loss': 5.6741943359375, 'Student Perplexity': 291.25360107421875, 'Distillation Loss': 5.675048828125, 'Learning Rate': 6.695312500000008e-05}
# {'Student Loss': 5.570556640625, 'Student Perplexity': 262.5802307128906, 'Distillation Loss': 5.7822265625, 'Learning Rate': 6.660156250000008e-05}
# {'Student Loss': 5.63720703125, 'Student Perplexity': 280.6777038574219, 'Distillation Loss': 5.571044921875, 'Learning Rate': 6.625000000000008e-05}
# {'Student Loss': 6.552490234375, 'Student Perplexity': 700.9876098632812, 'Distillation Loss': 5.018798828125, 'Learning Rate': 6.589843750000008e-05}
# {'Student Loss': 6.471435546875, 'Student Perplexity': 646.4110107421875, 'Distillation Loss': 4.924560546875, 'Learning Rate': 6.554687500000008e-05}
# {'Student Loss': 6.007568359375, 'Student Perplexity': 406.4936828613281, 'Distillation Loss': 5.439697265625, 'Learning Rate': 6.519531250000008e-05}
# {'Student Loss': 5.6295166015625, 'Student Perplexity': 278.5274353027344, 'Distillation Loss': 5.6015625, 'Learning Rate': 6.484375000000008e-05}
# {'Student Loss': 5.6507568359375, 'Student Perplexity': 284.5067138671875, 'Distillation Loss': 5.51953125, 'Learning Rate': 6.449218750000008e-05}
# {'Student Loss': 6.161865234375, 'Student Perplexity': 474.31195068359375, 'Distillation Loss': 5.16064453125, 'Learning Rate': 6.414062500000008e-05}
# {'Student Loss': 6.338623046875, 'Student Perplexity': 566.0164184570312, 'Distillation Loss': 5.047119140625, 'Learning Rate': 6.378906250000008e-05}
# {'Student Loss': 5.8895263671875, 'Student Perplexity': 361.2341613769531, 'Distillation Loss': 5.35400390625, 'Learning Rate': 6.343750000000009e-05}
# {'Student Loss': 5.7845458984375, 'Student Perplexity': 325.23431396484375, 'Distillation Loss': 5.39990234375, 'Learning Rate': 6.308593750000009e-05}
# {'Student Loss': 5.5140380859375, 'Student Perplexity': 248.1511688232422, 'Distillation Loss': 5.50830078125, 'Learning Rate': 6.273437500000009e-05}
# {'Student Loss': 6.1953125, 'Student Perplexity': 490.4446716308594, 'Distillation Loss': 5.116455078125, 'Learning Rate': 6.238281250000009e-05}
# {'Student Loss': 6.519287109375, 'Student Perplexity': 678.0947875976562, 'Distillation Loss': 4.90625, 'Learning Rate': 6.203125000000009e-05}
# {'Student Loss': 6.3828125, 'Student Perplexity': 591.5892333984375, 'Distillation Loss': 4.92724609375, 'Learning Rate': 6.167968750000009e-05}
# {'Student Loss': 5.90380859375, 'Student Perplexity': 366.4303894042969, 'Distillation Loss': 5.180908203125, 'Learning Rate': 6.132812500000009e-05}
# {'Student Loss': 5.48486328125, 'Student Perplexity': 241.0159912109375, 'Distillation Loss': 5.449462890625, 'Learning Rate': 6.097656250000009e-05}
# {'Student Loss': 5.681640625, 'Student Perplexity': 293.4304504394531, 'Distillation Loss': 5.404296875, 'Learning Rate': 6.062500000000009e-05}
# {'Student Loss': 5.9625244140625, 'Student Perplexity': 388.58984375, 'Distillation Loss': 5.19970703125, 'Learning Rate': 6.027343750000009e-05}
# {'Student Loss': 6.078125, 'Student Perplexity': 436.2105407714844, 'Distillation Loss': 5.065673828125, 'Learning Rate': 5.9921875000000086e-05}
# {'Student Loss': 5.899658203125, 'Student Perplexity': 364.9127197265625, 'Distillation Loss': 5.11328125, 'Learning Rate': 5.957031250000008e-05}
# {'Student Loss': 5.6807861328125, 'Student Perplexity': 293.1798095703125, 'Distillation Loss': 5.3251953125, 'Learning Rate': 5.921875000000008e-05}
# {'Student Loss': 5.66650390625, 'Student Perplexity': 289.0223083496094, 'Distillation Loss': 5.300048828125, 'Learning Rate': 5.886718750000008e-05}
# {'Student Loss': 5.864501953125, 'Student Perplexity': 352.306640625, 'Distillation Loss': 5.08251953125, 'Learning Rate': 5.851562500000008e-05}
# {'Student Loss': 6.282958984375, 'Student Perplexity': 535.3704833984375, 'Distillation Loss': 4.936767578125, 'Learning Rate': 5.816406250000008e-05}
# {'Student Loss': 6.3115234375, 'Student Perplexity': 550.883544921875, 'Distillation Loss': 4.941650390625, 'Learning Rate': 5.7812500000000084e-05}
# {'Student Loss': 6.034912109375, 'Student Perplexity': 417.7620849609375, 'Distillation Loss': 5.134521484375, 'Learning Rate': 5.7460937500000085e-05}
# {'Student Loss': 5.648681640625, 'Student Perplexity': 283.9169006347656, 'Distillation Loss': 5.294189453125, 'Learning Rate': 5.7109375000000085e-05}
# {'Student Loss': 5.443359375, 'Student Perplexity': 231.21762084960938, 'Distillation Loss': 5.351806640625, 'Learning Rate': 5.6757812500000086e-05}
# {'Student Loss': 5.5465087890625, 'Student Perplexity': 256.341064453125, 'Distillation Loss': 5.313720703125, 'Learning Rate': 5.640625000000009e-05}
# {'Student Loss': 5.917724609375, 'Student Perplexity': 371.5653076171875, 'Distillation Loss': 5.064697265625, 'Learning Rate': 5.605468750000009e-05}
# {'Student Loss': 6.01318359375, 'Student Perplexity': 408.78265380859375, 'Distillation Loss': 4.982421875, 'Learning Rate': 5.570312500000008e-05}
# {'Student Loss': 5.9234619140625, 'Student Perplexity': 373.7032165527344, 'Distillation Loss': 5.03125, 'Learning Rate': 5.535156250000008e-05}
# {'Student Loss': 5.770751953125, 'Student Perplexity': 320.7788391113281, 'Distillation Loss': 5.15625, 'Learning Rate': 5.500000000000008e-05}
# {'Student Loss': 5.6038818359375, 'Student Perplexity': 271.47821044921875, 'Distillation Loss': 5.240234375, 'Learning Rate': 5.4648437500000084e-05}
# {'Student Loss': 5.712890625, 'Student Perplexity': 302.74493408203125, 'Distillation Loss': 5.203369140625, 'Learning Rate': 5.429687500000008e-05}
# {'Student Loss': 5.941162109375, 'Student Perplexity': 380.376708984375, 'Distillation Loss': 4.971435546875, 'Learning Rate': 5.394531250000008e-05}
# {'Student Loss': 5.88232421875, 'Student Perplexity': 358.641845703125, 'Distillation Loss': 4.977783203125, 'Learning Rate': 5.359375000000008e-05}
# {'Student Loss': 5.900390625, 'Student Perplexity': 365.1800842285156, 'Distillation Loss': 5.113037109375, 'Learning Rate': 5.324218750000008e-05}
# {'Student Loss': 5.7095947265625, 'Student Perplexity': 301.7487487792969, 'Distillation Loss': 5.29345703125, 'Learning Rate': 5.289062500000008e-05}
# {'Student Loss': 5.5478515625, 'Student Perplexity': 256.68548583984375, 'Distillation Loss': 5.2890625, 'Learning Rate': 5.253906250000008e-05}
# {'Student Loss': 5.5963134765625, 'Student Perplexity': 269.4313049316406, 'Distillation Loss': 5.286865234375, 'Learning Rate': 5.218750000000008e-05}
# {'Student Loss': 5.7777099609375, 'Student Perplexity': 323.01861572265625, 'Distillation Loss': 5.12646484375, 'Learning Rate': 5.1835937500000083e-05}
# {'Student Loss': 5.9415283203125, 'Student Perplexity': 380.5160217285156, 'Distillation Loss': 5.016845703125, 'Learning Rate': 5.1484375000000084e-05}
# {'Student Loss': 5.841552734375, 'Student Perplexity': 344.3135681152344, 'Distillation Loss': 5.114013671875, 'Learning Rate': 5.1132812500000085e-05}
# {'Student Loss': 5.8758544921875, 'Student Perplexity': 356.3290100097656, 'Distillation Loss': 5.12255859375, 'Learning Rate': 5.0781250000000086e-05}
# {'Student Loss': 5.835205078125, 'Student Perplexity': 342.1348876953125, 'Distillation Loss': 5.135498046875, 'Learning Rate': 5.0429687500000087e-05}
# {'Student Loss': 5.87646484375, 'Student Perplexity': 356.54656982421875, 'Distillation Loss': 5.07763671875, 'Learning Rate': 5.007812500000009e-05}
# {'Student Loss': 6.027099609375, 'Student Perplexity': 414.51104736328125, 'Distillation Loss': 4.878173828125, 'Learning Rate': 4.972656250000009e-05}
# {'Student Loss': 5.989013671875, 'Student Perplexity': 399.0208435058594, 'Distillation Loss': 4.93603515625, 'Learning Rate': 4.937500000000009e-05}
# {'Student Loss': 5.7711181640625, 'Student Perplexity': 320.8963623046875, 'Distillation Loss': 5.111083984375, 'Learning Rate': 4.902343750000009e-05}
# {'Student Loss': 5.5540771484375, 'Student Perplexity': 258.2884826660156, 'Distillation Loss': 5.240234375, 'Learning Rate': 4.867187500000009e-05}
# {'Student Loss': 5.710693359375, 'Student Perplexity': 302.0804443359375, 'Distillation Loss': 5.168212890625, 'Learning Rate': 4.832031250000009e-05}
# {'Student Loss': 5.8289794921875, 'Student Perplexity': 340.0115051269531, 'Distillation Loss': 5.07666015625, 'Learning Rate': 4.796875000000009e-05}
# {'Student Loss': 5.6846923828125, 'Student Perplexity': 294.3273010253906, 'Distillation Loss': 5.11767578125, 'Learning Rate': 4.761718750000009e-05}
# {'Student Loss': 5.69970703125, 'Student Perplexity': 298.77984619140625, 'Distillation Loss': 5.26123046875, 'Learning Rate': 4.7265625000000093e-05}
# {'Student Loss': 5.5703125, 'Student Perplexity': 262.51611328125, 'Distillation Loss': 5.303955078125, 'Learning Rate': 4.6914062500000094e-05}
# {'Student Loss': 5.7518310546875, 'Student Perplexity': 314.7664794921875, 'Distillation Loss': 5.29296875, 'Learning Rate': 4.6562500000000095e-05}
# {'Student Loss': 5.771240234375, 'Student Perplexity': 320.9355163574219, 'Distillation Loss': 5.125244140625, 'Learning Rate': 4.6210937500000096e-05}
# {'Student Loss': 5.79736328125, 'Student Perplexity': 329.4298095703125, 'Distillation Loss': 5.078857421875, 'Learning Rate': 4.5859375000000097e-05}
# {'Student Loss': 5.7059326171875, 'Student Perplexity': 300.645751953125, 'Distillation Loss': 5.1220703125, 'Learning Rate': 4.55078125000001e-05}
# {'Student Loss': 5.5521240234375, 'Student Perplexity': 257.7845153808594, 'Distillation Loss': 5.403076171875, 'Learning Rate': 4.51562500000001e-05}
# {'Student Loss': 5.5238037109375, 'Student Perplexity': 250.5863800048828, 'Distillation Loss': 5.3427734375, 'Learning Rate': 4.48046875000001e-05}
# {'Student Loss': 5.6630859375, 'Student Perplexity': 288.0361328125, 'Distillation Loss': 5.18505859375, 'Learning Rate': 4.44531250000001e-05}
# {'Student Loss': 5.591064453125, 'Student Perplexity': 268.020751953125, 'Distillation Loss': 5.187255859375, 'Learning Rate': 4.41015625000001e-05}
# {'Student Loss': 5.902099609375, 'Student Perplexity': 365.8047180175781, 'Distillation Loss': 4.95068359375, 'Learning Rate': 4.37500000000001e-05}
# {'Student Loss': 5.7225341796875, 'Student Perplexity': 305.6785888671875, 'Distillation Loss': 5.12841796875, 'Learning Rate': 4.33984375000001e-05}
# {'Student Loss': 5.7734375, 'Student Perplexity': 321.6414794921875, 'Distillation Loss': 5.151123046875, 'Learning Rate': 4.30468750000001e-05}
# {'Student Loss': 5.55712890625, 'Student Perplexity': 259.07794189453125, 'Distillation Loss': 5.173095703125, 'Learning Rate': 4.2695312500000104e-05}
# {'Student Loss': 5.676025390625, 'Student Perplexity': 291.7873840332031, 'Distillation Loss': 5.139404296875, 'Learning Rate': 4.2343750000000104e-05}
# {'Student Loss': 5.831298828125, 'Student Perplexity': 340.801025390625, 'Distillation Loss': 5.080322265625, 'Learning Rate': 4.19921875000001e-05}
# {'Student Loss': 5.836181640625, 'Student Perplexity': 342.46917724609375, 'Distillation Loss': 5.0888671875, 'Learning Rate': 4.16406250000001e-05}
# {'Student Loss': 5.5279541015625, 'Student Perplexity': 251.62857055664062, 'Distillation Loss': 5.16357421875, 'Learning Rate': 4.12890625000001e-05}
# {'Student Loss': 5.677490234375, 'Student Perplexity': 292.2151184082031, 'Distillation Loss': 5.312255859375, 'Learning Rate': 4.09375000000001e-05}
# {'Student Loss': 5.3956298828125, 'Student Perplexity': 220.44094848632812, 'Distillation Loss': 5.38720703125, 'Learning Rate': 4.0585937500000095e-05}
# {'Student Loss': 5.4927978515625, 'Student Perplexity': 242.9359588623047, 'Distillation Loss': 5.243896484375, 'Learning Rate': 4.0234375000000095e-05}
# {'Student Loss': 6.05029296875, 'Student Perplexity': 424.2373046875, 'Distillation Loss': 4.975341796875, 'Learning Rate': 3.9882812500000096e-05}
# {'Student Loss': 6.06689453125, 'Student Perplexity': 431.3390808105469, 'Distillation Loss': 4.892333984375, 'Learning Rate': 3.95312500000001e-05}
# {'Student Loss': 5.794189453125, 'Student Perplexity': 328.3858947753906, 'Distillation Loss': 4.952392578125, 'Learning Rate': 3.91796875000001e-05}
# {'Student Loss': 5.65380859375, 'Student Perplexity': 285.37628173828125, 'Distillation Loss': 5.2333984375, 'Learning Rate': 3.88281250000001e-05}
# {'Student Loss': 5.596923828125, 'Student Perplexity': 269.5957946777344, 'Distillation Loss': 5.279541015625, 'Learning Rate': 3.84765625000001e-05}
# {'Student Loss': 5.5732421875, 'Student Perplexity': 263.2863464355469, 'Distillation Loss': 5.23974609375, 'Learning Rate': 3.81250000000001e-05}
# {'Student Loss': 5.5980224609375, 'Student Perplexity': 269.89215087890625, 'Distillation Loss': 5.171142578125, 'Learning Rate': 3.77734375000001e-05}
# {'Student Loss': 5.7674560546875, 'Student Perplexity': 319.72332763671875, 'Distillation Loss': 5.025146484375, 'Learning Rate': 3.74218750000001e-05}
# {'Student Loss': 5.90234375, 'Student Perplexity': 365.89404296875, 'Distillation Loss': 4.958984375, 'Learning Rate': 3.70703125000001e-05}
# {'Student Loss': 5.8951416015625, 'Student Perplexity': 363.2682800292969, 'Distillation Loss': 4.9560546875, 'Learning Rate': 3.67187500000001e-05}
# {'Student Loss': 5.78662109375, 'Student Perplexity': 325.9099426269531, 'Distillation Loss': 5.03369140625, 'Learning Rate': 3.6367187500000104e-05}
# {'Student Loss': 5.5970458984375, 'Student Perplexity': 269.62872314453125, 'Distillation Loss': 5.1357421875, 'Learning Rate': 3.6015625000000105e-05}
# {'Student Loss': 5.5723876953125, 'Student Perplexity': 263.06146240234375, 'Distillation Loss': 5.227783203125, 'Learning Rate': 3.56640625000001e-05}
# {'Student Loss': 5.5189208984375, 'Student Perplexity': 249.3657989501953, 'Distillation Loss': 5.21435546875, 'Learning Rate': 3.53125000000001e-05}
# {'Student Loss': 5.648193359375, 'Student Perplexity': 283.7783203125, 'Distillation Loss': 5.08740234375, 'Learning Rate': 3.49609375000001e-05}
# {'Student Loss': 6.067626953125, 'Student Perplexity': 431.6551208496094, 'Distillation Loss': 4.944580078125, 'Learning Rate': 3.46093750000001e-05}
# {'Student Loss': 5.822998046875, 'Student Perplexity': 337.98382568359375, 'Distillation Loss': 4.916015625, 'Learning Rate': 3.42578125000001e-05}
# {'Student Loss': 5.90625, 'Student Perplexity': 367.32611083984375, 'Distillation Loss': 4.991943359375, 'Learning Rate': 3.39062500000001e-05}
# {'Student Loss': 5.6878662109375, 'Student Perplexity': 295.2629089355469, 'Distillation Loss': 5.02099609375, 'Learning Rate': 3.35546875000001e-05}
# {'Student Loss': 5.65380859375, 'Student Perplexity': 285.37628173828125, 'Distillation Loss': 5.045166015625, 'Learning Rate': 3.3203125000000104e-05}
# {'Student Loss': 5.5509033203125, 'Student Perplexity': 257.47003173828125, 'Distillation Loss': 5.14306640625, 'Learning Rate': 3.2851562500000105e-05}
# {'Student Loss': 5.315185546875, 'Student Perplexity': 203.40225219726562, 'Distillation Loss': 5.237548828125, 'Learning Rate': 3.2500000000000106e-05}
# {'Student Loss': 5.5709228515625, 'Student Perplexity': 262.6763916015625, 'Distillation Loss': 5.05859375, 'Learning Rate': 3.2148437500000106e-05}
# {'Student Loss': 5.762451171875, 'Student Perplexity': 318.1271667480469, 'Distillation Loss': 5.033447265625, 'Learning Rate': 3.179687500000011e-05}
# {'Student Loss': 5.717041015625, 'Student Perplexity': 304.0040588378906, 'Distillation Loss': 5.0322265625, 'Learning Rate': 3.144531250000011e-05}
# {'Student Loss': 5.802001953125, 'Student Perplexity': 330.9614562988281, 'Distillation Loss': 5.00732421875, 'Learning Rate': 3.109375000000011e-05}
# {'Student Loss': 5.7503662109375, 'Student Perplexity': 314.3057556152344, 'Distillation Loss': 4.924560546875, 'Learning Rate': 3.074218750000011e-05}
# {'Student Loss': 5.5947265625, 'Student Perplexity': 269.00408935546875, 'Distillation Loss': 5.079833984375, 'Learning Rate': 3.0390625000000107e-05}
# {'Student Loss': 5.5594482421875, 'Student Perplexity': 259.67950439453125, 'Distillation Loss': 5.15478515625, 'Learning Rate': 3.0039062500000104e-05}
# {'Student Loss': 5.5556640625, 'Student Perplexity': 258.6986999511719, 'Distillation Loss': 5.1298828125, 'Learning Rate': 2.96875000000001e-05}
# {'Student Loss': 5.528076171875, 'Student Perplexity': 251.6593017578125, 'Distillation Loss': 5.177001953125, 'Learning Rate': 2.9335937500000102e-05}
# {'Student Loss': 5.68408203125, 'Student Perplexity': 294.147705078125, 'Distillation Loss': 5.037841796875, 'Learning Rate': 2.89843750000001e-05}
# {'Student Loss': 5.799560546875, 'Student Perplexity': 330.1544494628906, 'Distillation Loss': 4.93505859375, 'Learning Rate': 2.8632812500000097e-05}
# {'Student Loss': 5.771240234375, 'Student Perplexity': 320.9355163574219, 'Distillation Loss': 4.8614501953125, 'Learning Rate': 2.8281250000000095e-05}
# {'Student Loss': 5.8165283203125, 'Student Perplexity': 335.8042297363281, 'Distillation Loss': 4.899169921875, 'Learning Rate': 2.7929687500000092e-05}
# {'Student Loss': 5.8416748046875, 'Student Perplexity': 344.3555908203125, 'Distillation Loss': 5.01416015625, 'Learning Rate': 2.757812500000009e-05}
# {'Student Loss': 5.5445556640625, 'Student Perplexity': 255.8408660888672, 'Distillation Loss': 5.096435546875, 'Learning Rate': 2.722656250000009e-05}
# {'Student Loss': 5.4669189453125, 'Student Perplexity': 236.7296905517578, 'Distillation Loss': 5.267333984375, 'Learning Rate': 2.6875000000000087e-05}
# {'Student Loss': 5.542724609375, 'Student Perplexity': 255.3728485107422, 'Distillation Loss': 5.190673828125, 'Learning Rate': 2.6523437500000085e-05}
# {'Student Loss': 5.5279541015625, 'Student Perplexity': 251.62857055664062, 'Distillation Loss': 5.21484375, 'Learning Rate': 2.6171875000000086e-05}
# {'Student Loss': 5.5419921875, 'Student Perplexity': 255.1858673095703, 'Distillation Loss': 5.107421875, 'Learning Rate': 2.5820312500000086e-05}
# {'Student Loss': 5.688232421875, 'Student Perplexity': 295.3710632324219, 'Distillation Loss': 4.98486328125, 'Learning Rate': 2.5468750000000084e-05}
# {'Student Loss': 5.657470703125, 'Student Perplexity': 286.42327880859375, 'Distillation Loss': 5.053955078125, 'Learning Rate': 2.511718750000008e-05}
# {'Student Loss': 5.62255859375, 'Student Perplexity': 276.59619140625, 'Distillation Loss': 5.054443359375, 'Learning Rate': 2.4765625000000082e-05}
# {'Student Loss': 5.5172119140625, 'Student Perplexity': 248.94000244140625, 'Distillation Loss': 5.1259765625, 'Learning Rate': 2.441406250000008e-05}
# {'Student Loss': 5.615478515625, 'Student Perplexity': 274.644775390625, 'Distillation Loss': 5.11669921875, 'Learning Rate': 2.406250000000008e-05}
# {'Student Loss': 5.4010009765625, 'Student Perplexity': 221.62814331054688, 'Distillation Loss': 5.188720703125, 'Learning Rate': 2.3710937500000077e-05}
# {'Student Loss': 5.5474853515625, 'Student Perplexity': 256.59149169921875, 'Distillation Loss': 5.193115234375, 'Learning Rate': 2.3359375000000078e-05}
# {'Student Loss': 5.47998046875, 'Student Perplexity': 239.84202575683594, 'Distillation Loss': 5.1484375, 'Learning Rate': 2.3007812500000076e-05}
# {'Student Loss': 5.4617919921875, 'Student Perplexity': 235.5190887451172, 'Distillation Loss': 5.15380859375, 'Learning Rate': 2.2656250000000073e-05}
# {'Student Loss': 5.5382080078125, 'Student Perplexity': 254.22203063964844, 'Distillation Loss': 5.12451171875, 'Learning Rate': 2.2304687500000074e-05}
# {'Student Loss': 5.665283203125, 'Student Perplexity': 288.6697082519531, 'Distillation Loss': 5.078369140625, 'Learning Rate': 2.195312500000007e-05}
# {'Student Loss': 5.6068115234375, 'Student Perplexity': 272.27471923828125, 'Distillation Loss': 5.0751953125, 'Learning Rate': 2.160156250000007e-05}
# {'Student Loss': 5.78369140625, 'Student Perplexity': 324.9565124511719, 'Distillation Loss': 5.001708984375, 'Learning Rate': 2.1250000000000066e-05}
# {'Student Loss': 5.72216796875, 'Student Perplexity': 305.566650390625, 'Distillation Loss': 4.985107421875, 'Learning Rate': 2.0898437500000063e-05}
# {'Student Loss': 5.707763671875, 'Student Perplexity': 301.1967468261719, 'Distillation Loss': 5.0283203125, 'Learning Rate': 2.0546875000000064e-05}
# {'Student Loss': 5.685302734375, 'Student Perplexity': 294.5069885253906, 'Distillation Loss': 5.07470703125, 'Learning Rate': 2.0195312500000065e-05}
# {'Student Loss': 5.6099853515625, 'Student Perplexity': 273.1402282714844, 'Distillation Loss': 5.064208984375, 'Learning Rate': 1.9843750000000062e-05}
# {'Student Loss': 5.5623779296875, 'Student Perplexity': 260.44140625, 'Distillation Loss': 5.056884765625, 'Learning Rate': 1.9492187500000063e-05}
# {'Student Loss': 5.61669921875, 'Student Perplexity': 274.980224609375, 'Distillation Loss': 5.096923828125, 'Learning Rate': 1.914062500000006e-05}
# {'Student Loss': 5.6173095703125, 'Student Perplexity': 275.14813232421875, 'Distillation Loss': 5.154296875, 'Learning Rate': 1.8789062500000058e-05}
# {'Student Loss': 5.7078857421875, 'Student Perplexity': 301.2335205078125, 'Distillation Loss': 5.113037109375, 'Learning Rate': 1.843750000000006e-05}
# {'Student Loss': 5.5888671875, 'Student Perplexity': 267.4324951171875, 'Distillation Loss': 5.04150390625, 'Learning Rate': 1.8085937500000056e-05}
# {'Student Loss': 5.584228515625, 'Student Perplexity': 266.19482421875, 'Distillation Loss': 5.15869140625, 'Learning Rate': 1.7734375000000053e-05}
# {'Student Loss': 5.6014404296875, 'Student Perplexity': 270.81622314453125, 'Distillation Loss': 5.0816650390625, 'Learning Rate': 1.738281250000005e-05}
# {'Student Loss': 5.63134765625, 'Student Perplexity': 279.03790283203125, 'Distillation Loss': 5.043212890625, 'Learning Rate': 1.703125000000005e-05}
# {'Student Loss': 5.5908203125, 'Student Perplexity': 267.955322265625, 'Distillation Loss': 5.05078125, 'Learning Rate': 1.667968750000005e-05}
# {'Student Loss': 5.68115234375, 'Student Perplexity': 293.2872009277344, 'Distillation Loss': 5.087890625, 'Learning Rate': 1.6328125000000046e-05}
# {'Student Loss': 5.6351318359375, 'Student Perplexity': 280.0958557128906, 'Distillation Loss': 5.113525390625, 'Learning Rate': 1.5976562500000044e-05}
# {'Student Loss': 5.80224609375, 'Student Perplexity': 331.0422668457031, 'Distillation Loss': 5.085693359375, 'Learning Rate': 1.562500000000004e-05}
# {'Student Loss': 5.6015625, 'Student Perplexity': 270.8492736816406, 'Distillation Loss': 5.106201171875, 'Learning Rate': 1.5273437500000042e-05}
# {'Student Loss': 5.5283203125, 'Student Perplexity': 251.7207489013672, 'Distillation Loss': 5.08056640625, 'Learning Rate': 1.492187500000004e-05}
# {'Student Loss': 5.55859375, 'Student Perplexity': 259.45770263671875, 'Distillation Loss': 5.04638671875, 'Learning Rate': 1.457031250000004e-05}
# {'Student Loss': 5.654052734375, 'Student Perplexity': 285.4459533691406, 'Distillation Loss': 5.07666015625, 'Learning Rate': 1.4218750000000039e-05}
# {'Student Loss': 5.560546875, 'Student Perplexity': 259.9649658203125, 'Distillation Loss': 5.1025390625, 'Learning Rate': 1.3867187500000038e-05}
# {'Student Loss': 5.6036376953125, 'Student Perplexity': 271.41192626953125, 'Distillation Loss': 5.071533203125, 'Learning Rate': 1.3515625000000037e-05}
# {'Student Loss': 5.552978515625, 'Student Perplexity': 258.0048828125, 'Distillation Loss': 5.091064453125, 'Learning Rate': 1.3164062500000036e-05}
# {'Student Loss': 5.6036376953125, 'Student Perplexity': 271.41192626953125, 'Distillation Loss': 5.0830078125, 'Learning Rate': 1.2812500000000035e-05}
# {'Student Loss': 5.636474609375, 'Student Perplexity': 280.4721984863281, 'Distillation Loss': 5.06396484375, 'Learning Rate': 1.2460937500000034e-05}
# {'Student Loss': 5.4771728515625, 'Student Perplexity': 239.16958618164062, 'Distillation Loss': 5.105712890625, 'Learning Rate': 1.2109375000000033e-05}
# {'Student Loss': 5.4986572265625, 'Student Perplexity': 244.36358642578125, 'Distillation Loss': 5.09130859375, 'Learning Rate': 1.1757812500000033e-05}
# {'Student Loss': 5.6234130859375, 'Student Perplexity': 276.8326416015625, 'Distillation Loss': 5.147705078125, 'Learning Rate': 1.1406250000000032e-05}
# {'Student Loss': 5.65771484375, 'Student Perplexity': 286.49322509765625, 'Distillation Loss': 5.115234375, 'Learning Rate': 1.105468750000003e-05}
# {'Student Loss': 5.6357421875, 'Student Perplexity': 280.266845703125, 'Distillation Loss': 5.067138671875, 'Learning Rate': 1.070312500000003e-05}
# {'Student Loss': 5.7188720703125, 'Student Perplexity': 304.56121826171875, 'Distillation Loss': 5.051513671875, 'Learning Rate': 1.0351562500000029e-05}
# {'Student Loss': 5.5408935546875, 'Student Perplexity': 254.90567016601562, 'Distillation Loss': 5.09375, 'Learning Rate': 1.0000000000000028e-05}
# ('/content/drive/MyDrive/project/model/tokenizer/distillpythia/tokenizer_config.json',
#  '/content/drive/MyDrive/project/model/tokenizer/distillpythia/special_tokens_map.json',
#  '/content/drive/MyDrive/project/model/tokenizer/distillpythia/tokenizer.json')

# %%
from transformers import pipeline

model = AutoModelForCausalLM.from_pretrained(model_save_path)
tokenizer = AutoTokenizer.from_pretrained(tokenizer_save_path)
predictor = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0)

batch_size = 16

results = {'Input Text': [], 'Predicted Text': [], 'Correct Text': []}

for i in tqdm(range(0, len(test_dataset), batch_size)):
    batch = test_dataset[i:i + batch_size]
    input_texts = batch['input']
    correct_texts = batch['target']

    generated_outputs = predictor(input_texts, max_length=1024, truncation=True)
    # print(generated_outputs)
    predicted_texts = [output[0]['generated_text'] for output in generated_outputs]

    results['Input Text'].extend(input_texts)
    results['Predicted Text'].extend(predicted_texts)
    results['Correct Text'].extend(correct_texts)

df_results = pd.DataFrame(results)
df_results.to_csv('/content/drive/MyDrive/project/dataset_dp.csv', index=False)
print("Predictions have been saved to CSV.")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 100%|██████████| 423/423 [27:40<00:00,  3.93s/it]
# Predictions have been saved to CSV.

# %%
import evaluate

df = pd.read_csv('/content/drive/MyDrive/project/dataset_dp.csv')


dp_predicted_text_list = df['Predicted Text'].tolist()
actual_test_list = df['Correct Text'].tolist()

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")

print("Knowledge Distillation Predictions BLEU Results:")
base_bleu_results = bleu.compute(predictions=dp_predicted_text_list, references=[[ref] for ref in actual_test_list])
print(base_bleu_results)

print("Knowledge Distillation Predictions ROUGE Results:")
base_rouge_results = rouge.compute(predictions=dp_predicted_text_list, references=actual_test_list)
print(base_rouge_results)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Knowledge Distillation Predictions BLEU Results:
# {'bleu': 0.31968919524799616, 'precisions': [0.40433467494036546, 0.34149559872388047, 0.29493912594446287, 0.25647990650420616], 'brevity_penalty': 1.0, 'length_ratio': 2.1584295639250284, 'translation_length': 365979, 'reference_length': 169558}
# Knowledge Distillation Predictions ROUGE Results:
# {'rouge1': 0.7771724515230958, 'rouge2': 0.6678408384005026, 'rougeL': 0.7687492499707335, 'rougeLsum': 0.7705764019906508}
